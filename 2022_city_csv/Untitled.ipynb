# %%
import pandas as pd
import numpy as np
df = pd.read_csv('merged_cities_2022.csv')
df.head()
# Out:
#                   data  agrigento_infected  alessandria_infected  \
# 0  2022-01-01 17:00:00               22148                 41768
# 1  2022-01-02 17:00:00               22723                 42110
# 2  2022-01-03 17:00:00               22985                 42574
# 3  2022-01-04 17:00:00               23731                 44459
# 4  2022-01-05 17:00:00               24412                 45814
#
#    ancona_infected  aosta_infected  arezzo_infected  ascoli_piceno_infected  \
# 0            45997           15287            36261                   16932
# 1            46394           15410            36868                   16970
# 2            46600           15592            37473                   16981
# 3            47261           15844            39018                   17332
# 4            47912           16089            40282                   17688
#
#    asti_infected  avellino_infected  bari_infected  ...  trieste_infected  \
# ...

# %%
df.columns
# Out:
# Index(['data', 'agrigento_infected', 'alessandria_infected', 'ancona_infected',
#        'aosta_infected', 'arezzo_infected', 'ascoli_piceno_infected',
#        'asti_infected', 'avellino_infected', 'bari_infected',
#        ...
#        'trieste_infected', 'udine_infected', 'varese_infected',
#        'venezia_infected', 'verbano-cusio-ossola_infected',
#        'vercelli_infected', 'verona_infected', 'vibo_valentia_infected',
#        'vicenza_infected', 'viterbo_infected'],
#       dtype='object', length=108)
